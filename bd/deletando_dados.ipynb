# %%
import sqlite3 as sql3

# %%
# Gerando conexão e criando cursor
conexao = sql3.connect('titulo.db')
cursor = conexao.cursor()

# %%
# Deletando dados com query por meio do crusor
cursor.execute(
    '''
        DELETE FROM filmes
        WHERE id = ?
    ''',
    (1, )
)
conexao.commit()
conexao.close()
print("Dado execluído!")
# Out:
# Dado execluído!
