# %%
import sqlite3 as sql3

# %%
# Gerando conexão e criando crusor
conexao = sql3.connect('titulo.db')
cursor =  conexao.cursor()

# %%
# Atualizando dados com cursor
cursor.execute(
    '''
        UPDATE filmes SET nome = ?
        WHERE  id = ?
    ''',
    ("Matrix", 2)
)
conexao.commit()
conexao.close()
print("Valor atualizado!")
